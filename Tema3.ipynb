# %%
import warnings
from datetime import datetime

warnings.simplefilter("ignore", DeprecationWarning)
warnings.simplefilter("ignore", FutureWarning)

# !pip -q install mlxtend

# %% [markdown]
# Romania

# %%
import pandas as pd
import numpy as np
import time

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth, apriori, association_rules
from google.colab import drive
drive.mount('/content/drive')

PATH = "/content/drive/MyDrive/consumption_user.csv"
df = pd.read_csv(PATH, low_memory=False)

print("Shape:", df.shape)
df.head()
# Out:
# Mounted at /content/drive
# Shape: (257952, 80)
#    SUBJECT  ROUND  SURVEY_DAY  RESPONDER  SEASON  CONSUMPTION_DAY  \
# 0        1      1           1          1     NaN              NaN
# 1        1      1           1          1     NaN              NaN
# 2        1      1           1          1     NaN              NaN
# 3        1      1           1          1     NaN              NaN
# 4        1      1           1          1     NaN              NaN
#
#    CONSUMPTION_MONTH  CONSUMPTION_YEAR  WEEK_DAY  EXCEPTION_DAY  ...  \
# 0                NaN              2012         2              1  ...
# 1                NaN              2012         2              1  ...
# 2                NaN              2012         2              1  ...
# 3                NaN              2012         2              1  ...
# 4                NaN              2012         2              1  ...
#
#    RETOL_mcg  VITD_mcg  VITE_mg  VITK_mcg  PHY_mg  N6_g EPA_DHA_g ALA_g  \
# 0        NaN       1.6     0.35      5.12     NaN  3.50       0.0  0.20
# 1        NaN       0.0     0.57     11.55     NaN  1.32       0.0  0.12
# 2        NaN       0.0     0.93      2.80     NaN  0.87       0.0  0.13
# 3        NaN       0.0     0.00      0.00     NaN   NaN       0.0   NaN
# 4        NaN       0.0     0.03     60.68     NaN   NaN       0.0   NaN
#
#   EAT_SEQ    VERSION
# 0       1  16-Jun-21
# 1       1        NaN
# 2       1        NaN
# 3       2        NaN
# 4       1        NaN
#
# [5 rows x 80 columns]

# %%
keep_cols = ["SUBJECT", "SURVEY_DAY", "INGREDIENT_ENG", "FOOD_AMOUNT_CONS"]
data = df[keep_cols].copy()

data["ITEM"] = data["INGREDIENT_ENG"].astype(str).str.strip()
data = data[data["ITEM"].notna() & (data["ITEM"] != "")]

data["FOOD_AMOUNT_CONS"] = pd.to_numeric(data["FOOD_AMOUNT_CONS"], errors="coerce")

print("Rânduri după curățare:", data.shape[0])
data.head()
# Out:
# Rânduri după curățare: 257952
#    SUBJECT  SURVEY_DAY     INGREDIENT_ENG  FOOD_AMOUNT_CONS               ITEM
# 0        1           1             SALAMI             160.0             SALAMI
# 1        1           1              BREAD             150.0              BREAD
# 2        1           1             BUTTER              40.0             BUTTER
# 3        1           1                TEA             250.0                TEA
# 4        1           1  VEGETABLES, MIXED               3.7  VEGETABLES, MIXED

# %%
data["TID"] = data["SUBJECT"].astype(str) + "_D" + data["SURVEY_DAY"].astype("Int64").astype(str)

print("Tranzacții (TID) unice:", data["TID"].nunique())
print("Item-uri unice:", data["ITEM"].nunique())
data[["TID", "ITEM"]].head()
# Out:
# Tranzacții (TID) unice: 9666
# Item-uri unice: 1033
#     TID               ITEM
# 0  1_D1             SALAMI
# 1  1_D1              BREAD
# 2  1_D1             BUTTER
# 3  1_D1                TEA
# 4  1_D1  VEGETABLES, MIXED

# %%
transactions = (
    data.drop_duplicates(["TID", "ITEM"])
        .groupby("TID")["ITEM"]
        .apply(list)
        .tolist()
)

print("Număr coșuri:", len(transactions))
print("Exemplu coș:", transactions[0][:15])

te = TransactionEncoder()
basket = te.fit(transactions).transform(transactions)
basket_df = pd.DataFrame(basket, columns=te.columns_)

print("Basket DF shape:", basket_df.shape)
# Out:
# Număr coșuri: 9666
# Exemplu coș: ['BREAD, BROWN', 'TOMATO', 'HAM', 'COFFEE, UNSWEETENED', 'SALT', 'WATER (DRINKING  WATER)', 'PARSLEY ROOT', 'ZUCCHINI', 'BORSCHT, RAW', 'CARROT', 'PEPPER', 'GREEN BEANS, PODS', 'VEGETABLES, MIXED', 'ONION', 'MILK']
# Basket DF shape: (9666, 1033)

# %%
MIN_ITEM_SUPPORT = 0.05
item_support = basket_df.mean()

common_items = item_support[item_support >= MIN_ITEM_SUPPORT].index
basket_df_small = basket_df[common_items]

print("După filtrare item-uri:", basket_df_small.shape)
# Out:
# După filtrare item-uri: (9666, 76)

# %%
MIN_SUPPORT = 0.05
start = time.time()

freq_fp = fpgrowth(
    basket_df_small,
    min_support=MIN_SUPPORT,
    use_colnames=True,
    max_len=2
)

t_fp = time.time() - start
print("FP-Growth time:", t_fp)
print("Nr itemsets:", len(freq_fp))

freq_fp["len"] = freq_fp["itemsets"].apply(len)
freq_fp.sort_values(["support", "len"], ascending=False).head(10)
# Out:
# FP-Growth time: 32.129029989242554
# Nr itemsets: 922
#      support         itemsets  len
# 0   0.942582           (SALT)    1
# 1   0.869646            (OIL)    1
# 76  0.858473      (OIL, SALT)    2
# 2   0.832920          (ONION)    1
# 77  0.826609    (SALT, ONION)    2
# 3   0.778502         (CARROT)    1
# 79  0.773743   (SALT, CARROT)    2
# 4   0.772605          (BREAD)    1
# 78  0.765467     (OIL, ONION)    2
# 80  0.757604  (ONION, CARROT)    2

# %%
start = time.time()

rules_fp = association_rules(freq_fp, metric="confidence", min_threshold=0.3)

t_rules = time.time() - start
print("Rules time:", t_rules)
print("Nr rules (brut):", len(rules_fp))

rules_fp = rules_fp[(rules_fp["lift"] > 1.0)].copy()
rules_fp.sort_values(["lift", "confidence"], ascending=False).head(10)
# Out:
# Rules time: 0.014458179473876953
# Nr rules (brut): 1082
#            antecedents        consequents  antecedent support  \
# 867   (PASTA, NOODLES)    (CHICKEN BROTH)            0.159321
# 866    (CHICKEN BROTH)   (PASTA, NOODLES)            0.095386
# 856    (CHICKEN BROTH)     (POULTRY MEAT)            0.095386
# 855     (POULTRY MEAT)    (CHICKEN BROTH)            0.172771
# 692            (PASTA)  (CHEESE, TELEMEA)            0.081316
# 693  (CHEESE, TELEMEA)            (PASTA)            0.108421
# 352       (MEAT BROTH)             (RICE)            0.052555
# 688            (PASTA)       (CONDIMENTS)            0.081316
# 835   (PASTA, NOODLES)     (POULTRY MEAT)            0.159321
# 834     (POULTRY MEAT)   (PASTA, NOODLES)            0.172771
#
#      consequent support   support  confidence      lift  representativity  \
# 867            0.095386  0.095282    0.598052  6.269816               1.0
# 866            0.159321  0.095282    0.998915  6.269816               1.0
# 856            0.172771  0.095386    1.000000  5.788024               1.0
# 855            0.095386  0.095386    0.552096  5.788024               1.0
# 692            0.108421  0.050383    0.619593  5.714680               1.0
# 693            0.081316  0.050383    0.464695  5.714680               1.0
# 352            0.245189  0.052038    0.990157  4.038338               1.0
# 688            0.241361  0.070246    0.863868  3.579145               1.0
# 835            0.172771  0.097455    0.611688  3.540467               1.0
# 834            0.159321  0.097455    0.564072  3.540467               1.0
#
#      leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 867  0.080085    2.250575       0.999794  0.597664   0.555669    0.798484
# 866  0.080085  775.105731       0.929132  0.597664   0.998710    0.798484
# 856  0.078906         inf       0.914456  0.552096   1.000000    0.776048
# 855  0.078906    2.019660       1.000000  0.552096   0.504867    0.776048
# 692  0.041566    2.343749       0.898037  0.361544   0.573333    0.542144
# 693  0.041566    1.716187       0.925338  0.361544   0.417313    0.542144
# 352  0.039152   76.688765       0.794108  0.211789   0.986960    0.601197
# 688  0.050620    5.572803       0.784387  0.278279   0.820557    0.577455
# 835  0.069929    2.130323       0.853538  0.415344   0.530588    0.587880
# 834  0.069929    1.928480       0.867415  0.415344   0.481457    0.587880

# %%
start = time.time()

freq_ap = apriori(
    basket_df_small,
    min_support=MIN_SUPPORT,
    use_colnames=True,
    max_len=2
)

t_ap = time.time() - start
print("Apriori time:", t_ap)
print("Nr itemsets:", len(freq_ap))

start = time.time()
rules_ap = association_rules(freq_ap, metric="confidence", min_threshold=0.3)
t_ap_rules = time.time() - start

rules_ap = rules_ap[rules_ap["lift"] > 1.0].copy()

print("Apriori rules time:", t_ap_rules)
print("Nr rules:", len(rules_ap))

rules_ap.sort_values(["lift", "confidence"], ascending=False).head(10)
# Out:
# Apriori time: 0.17417287826538086
# Nr itemsets: 922
# Apriori rules time: 0.01728963851928711
# Nr rules: 839
#            antecedents        consequents  antecedent support  \
# 441   (PASTA, NOODLES)    (CHICKEN BROTH)            0.159321
# 440    (CHICKEN BROTH)   (PASTA, NOODLES)            0.095386
# 444    (CHICKEN BROTH)     (POULTRY MEAT)            0.095386
# 443     (POULTRY MEAT)    (CHICKEN BROTH)            0.172771
# 429            (PASTA)  (CHEESE, TELEMEA)            0.081316
# 430  (CHEESE, TELEMEA)            (PASTA)            0.108421
# 764       (MEAT BROTH)             (RICE)            0.052555
# 511            (PASTA)       (CONDIMENTS)            0.081316
# 922   (PASTA, NOODLES)     (POULTRY MEAT)            0.159321
# 921     (POULTRY MEAT)   (PASTA, NOODLES)            0.172771
#
#      consequent support   support  confidence      lift  representativity  \
# 441            0.095386  0.095282    0.598052  6.269816               1.0
# 440            0.159321  0.095282    0.998915  6.269816               1.0
# 444            0.172771  0.095386    1.000000  5.788024               1.0
# 443            0.095386  0.095386    0.552096  5.788024               1.0
# 429            0.108421  0.050383    0.619593  5.714680               1.0
# 430            0.081316  0.050383    0.464695  5.714680               1.0
# 764            0.245189  0.052038    0.990157  4.038338               1.0
# 511            0.241361  0.070246    0.863868  3.579145               1.0
# 922            0.172771  0.097455    0.611688  3.540467               1.0
# 921            0.159321  0.097455    0.564072  3.540467               1.0
#
#      leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 441  0.080085    2.250575       0.999794  0.597664   0.555669    0.798484
# 440  0.080085  775.105731       0.929132  0.597664   0.998710    0.798484
# 444  0.078906         inf       0.914456  0.552096   1.000000    0.776048
# 443  0.078906    2.019660       1.000000  0.552096   0.504867    0.776048
# 429  0.041566    2.343749       0.898037  0.361544   0.573333    0.542144
# 430  0.041566    1.716187       0.925338  0.361544   0.417313    0.542144
# 764  0.039152   76.688765       0.794108  0.211789   0.986960    0.601197
# 511  0.050620    5.572803       0.784387  0.278279   0.820557    0.577455
# 922  0.069929    2.130323       0.853538  0.415344   0.530588    0.587880
# 921  0.069929    1.928480       0.867415  0.415344   0.481457    0.587880

# %%
basket_sizes_ro = [len(t) for t in transactions]

print("ROMÂNIA – statistici generale")
print("Nr tranzacții:", len(transactions))
print("Nr item-uri unice:", basket_df.shape[1])
print("Dimensiune coș (min / medie / max):",
      min(basket_sizes_ro),
      round(np.mean(basket_sizes_ro), 2),
      max(basket_sizes_ro))
# Out:
# ROMÂNIA – statistici generale
# Nr tranzacții: 9666
# Nr item-uri unice: 1033
# Dimensiune coș (min / medie / max): 1 20.73 50

# %%
summary = pd.DataFrame([
    {"Algoritm":"FP-Growth", "time_itemsets":t_fp, "nr_itemsets":len(freq_fp), "time_rules":t_rules, "nr_rules":len(rules_fp)},
    {"Algoritm":"Apriori",   "time_itemsets":t_ap, "nr_itemsets":len(freq_ap), "time_rules":t_ap_rules, "nr_rules":len(rules_ap)},
])

summary
# Out:
#     Algoritm  time_itemsets  nr_itemsets  time_rules  nr_rules
# 0  FP-Growth      32.129030          922    0.014458       839
# 1    Apriori       0.174173          922    0.017290       839

# %% [markdown]
# Italia

# %%
PATH_IT = "/content/drive/MyDrive/consumption_italy.csv"

df_it = pd.read_csv(
    PATH_IT,
    low_memory=False,
    encoding="latin1"
)

print(df_it.shape)
df_it.head()
# Out:
# (285589, 77)
#    SUBJECT  ROUND  SURVEY_DAY  RESPONDER  SEASON  CONSUMPTION_DAY  \
# 0        1      1           1        NaN     NaN               28
# 1        1      1           1        NaN     NaN               28
# 2        1      1           1        NaN     NaN               28
# 3        1      1           1        NaN     NaN               28
# 4        1      1           1        NaN     NaN               28
#
#    CONSUMPTION_MONTH  CONSUMPTION_YEAR  WEEK_DAY  EXCEPTION_DAY  ...  \
# 0                  6              2006         4              1  ...
# 1                  6              2006         4              1  ...
# 2                  6              2006         4              1  ...
# 3                  6              2006         4              1  ...
# 4                  6              2006         4              1  ...
#
#    VITA_RAE_mcg  VITA_RE_mcg  BCAROT_mcg  RETOL_mcg  VITD_mcg  VITE_mg  \
# 0             0          NaN           0          0      0.00     0.21
# 1            52          NaN          25         48      0.02     0.10
# 2             0          NaN           0          0      0.00     0.00
# 3             0          NaN           0          0      0.00     0.00
# 4            76          NaN         454          0      0.00     1.02
#
#    VITK_mcg  PHY_mg  EAT_SEQ       VERSION
# 0       NaN     NaN        1  16 June 2021
# 1       NaN     NaN        1           NaN
# 2       NaN     NaN        1           NaN
# 3       NaN     NaN        1           NaN
# 4       NaN     NaN        1           NaN
#
# [5 rows x 77 columns]

# %%
keep_cols = ["SUBJECT", "SURVEY_DAY", "INGREDIENT_ENG", "FOOD_AMOUNT_CONS"]
data_it = df_it[keep_cols].copy()

data_it["ITEM"] = data_it["INGREDIENT_ENG"].astype(str).str.strip()
data_it = data_it[data_it["ITEM"].notna() & (data_it["ITEM"] != "")]

data_it["FOOD_AMOUNT_CONS"] = pd.to_numeric(
    data_it["FOOD_AMOUNT_CONS"], errors="coerce"
)

print("Rânduri după curățare (IT):", data_it.shape[0])
data_it.head()
# Out:
# Rânduri după curățare (IT): 285589
#    SUBJECT  SURVEY_DAY                                     INGREDIENT_ENG  \
# 0        1           1  Cereals ready-to-eat, crispy oat flakes, "Extr...
# 1        1           1                            Milk, cow, semi-skimmed
# 2        1           1                                              Sugar
# 3        1           1                        Pasta, unenriched, dry, raw
# 4        1           1                      Tomato, peeled tomato, canned
#
#    FOOD_AMOUNT_CONS                                               ITEM
# 0               NaN  Cereals ready-to-eat, crispy oat flakes, "Extr...
# 1               NaN                            Milk, cow, semi-skimmed
# 2               NaN                                              Sugar
# 3               NaN                        Pasta, unenriched, dry, raw
# 4               NaN                      Tomato, peeled tomato, canned

# %%
data_it["TID"] = (
    data_it["SUBJECT"].astype(str)
    + "_D"
    + data_it["SURVEY_DAY"].astype("Int64").astype(str)
)

print("Tranzacții (TID) unice IT:", data_it["TID"].nunique())
print("Item-uri unice IT:", data_it["ITEM"].nunique())
data_it[["TID", "ITEM"]].head()
# Out:
# Tranzacții (TID) unice IT: 9969
# Item-uri unice IT: 1112
#     TID                                               ITEM
# 0  1_D1  Cereals ready-to-eat, crispy oat flakes, "Extr...
# 1  1_D1                            Milk, cow, semi-skimmed
# 2  1_D1                                              Sugar
# 3  1_D1                        Pasta, unenriched, dry, raw
# 4  1_D1                      Tomato, peeled tomato, canned

# %%
transactions_it = (
    data_it.drop_duplicates(["TID", "ITEM"])
           .groupby("TID")["ITEM"]
           .apply(list)
           .tolist()
)

print("Număr coșuri IT:", len(transactions_it))
print("Exemplu coș IT:", transactions_it[0][:15])

te = TransactionEncoder()
basket_it = te.fit(transactions_it).transform(transactions_it)
basket_df_it = pd.DataFrame(basket_it, columns=te.columns_)

print("Basket DF IT shape:", basket_df_it.shape)
# Out:
# Număr coșuri IT: 9969
# Exemplu coș IT: ['Coffee, brewed, espresso, homemade, without sugar', 'Cake, commercially prepared, sponge cake type, "Buondì"', 'Water, bottled water - Leggera', 'Coffee, brewed, espresso, restaurant, bar-prepared, without sugar', 'Pasta, unenriched, dry, raw', 'Tomato, peeled tomato, canned', 'Garlic, raw', 'Parsley, raw', 'Caper, all types', 'Olive, black olive, processed', 'Fish, anchovy, raw', 'Vegetable oil, olive oil', 'Cheese, Gorgonzola, from cow milk', 'Apple, unpeeled, fresh', 'Pizza, white pizza']
# Basket DF IT shape: (9969, 1112)

# %%
MIN_ITEM_SUPPORT = 0.05
item_support_it = basket_df_it.mean()

common_items_it = item_support_it[item_support_it >= MIN_ITEM_SUPPORT].index
basket_df_small_it = basket_df_it[common_items_it]

print("După filtrare item-uri IT:", basket_df_small_it.shape)
# Out:
# După filtrare item-uri IT: (9969, 84)

# %%
MIN_SUPPORT = 0.05
start = time.time()

freq_fp_it = fpgrowth(
    basket_df_small_it,
    min_support=MIN_SUPPORT,
    use_colnames=True,
    max_len=2
)

t_fp_it = time.time() - start
print("FP-Growth time IT:", t_fp_it)
print("Nr itemsets IT:", len(freq_fp_it))

freq_fp_it["len"] = freq_fp_it["itemsets"].apply(len)
freq_fp_it.sort_values(["support", "len"], ascending=False).head(10)
# Out:
# FP-Growth time IT: 33.7542827129364
# Nr itemsets IT: 939
#       support                                           itemsets  len
# 0    0.918347                         (Vegetable oil, olive oil)    1
# 15   0.726452                                            (Sugar)    1
# 1    0.676497  (Coffee, brewed, espresso, homemade, without s...    1
# 205  0.674090                  (Vegetable oil, olive oil, Sugar)    2
# 84   0.629451  (Vegetable oil, olive oil, Coffee, brewed, esp...    2
# 16   0.612098                                       (Onion, raw)    1
# 206  0.588023             (Vegetable oil, olive oil, Onion, raw)    2
# 2    0.582506                      (Pasta, unenriched, dry, raw)    1
# 86   0.560036  (Vegetable oil, olive oil, Pasta, unenriched, ...    2
# 85   0.540676  (Sugar, Coffee, brewed, espresso, homemade, wi...    2

# %%
start = time.time()

rules_fp_it = association_rules(
    freq_fp_it,
    metric="confidence",
    min_threshold=0.3
)

t_rules_it = time.time() - start
print("Rules time IT:", t_rules_it)
print("Nr rules (brut) IT:", len(rules_fp_it))

rules_fp_it = rules_fp_it[rules_fp_it["lift"] > 1.0].copy()

rules_fp_it.sort_values(
    ["lift", "confidence"],
    ascending=False
).head(10)
# Out:
# Rules time IT: 0.014131307601928711
# Nr rules (brut) IT: 980
#                           antecedents                       consequents  \
# 612                   (Cucumber, raw)   (Red chicory, "Radicchio", raw)
# 611   (Red chicory, "Radicchio", raw)                   (Cucumber, raw)
# 598   (Red chicory, "Radicchio", raw)                     (Fennel, raw)
# 597                     (Fennel, raw)   (Red chicory, "Radicchio", raw)
# 439       (Yeast, beer yeast tablets)      (Vegetable oil, mixed seeds)
# 438      (Vegetable oil, mixed seeds)       (Yeast, beer yeast tablets)
# 614                   (Cucumber, raw)                     (Fennel, raw)
# 613                     (Fennel, raw)                   (Cucumber, raw)
# 437  (Cheese, Mozzarella, cow's milk)       (Yeast, beer yeast tablets)
# 436       (Yeast, beer yeast tablets)  (Cheese, Mozzarella, cow's milk)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 612            0.089377            0.110041  0.064801    0.725028  6.588701
# 611            0.110041            0.089377  0.064801    0.588879  6.588701
# 598            0.110041            0.134718  0.083659    0.760255  5.643324
# 597            0.134718            0.110041  0.083659    0.620998  5.643324
# 439            0.137627            0.156385  0.120975    0.879009  5.620807
# 438            0.156385            0.137627  0.120975    0.773573  5.620807
# 614            0.089377            0.134718  0.064701    0.723906  5.373504
# 613            0.134718            0.089377  0.064701    0.480268  5.373504
# 437            0.241749            0.137627  0.123082    0.509129  3.699346
# 436            0.137627            0.241749  0.123082    0.894315  3.699346
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 612               1.0  0.054966    3.236544       0.931478  0.481371
# 611               1.0  0.054966    2.214974       0.953106  0.481371
# 598               1.0  0.068835    3.609182       0.924537  0.519303
# 597               1.0  0.068835    2.348163       0.950903  0.519303
# 439               1.0  0.099452    6.972531       0.953287  0.699130
# 438               1.0  0.099452    3.808612       0.974484  0.699130
# 614               1.0  0.052660    3.134011       0.893786  0.405916
# 613               1.0  0.052660    1.752101       0.940620  0.405916
# 437               1.0  0.089810    1.756821       0.962323  0.480235
# 436               1.0  0.089810    7.174619       0.846132  0.480235
#
#      certainty  kulczynski
# 612   0.691028    0.656953
# 611   0.548527    0.656953
# 598   0.722929    0.690627
# 597   0.574135    0.690627
# 439   0.856580    0.826291
# 438   0.737437    0.826291
# 614   0.680920    0.602087
# 613   0.429257    0.602087
# 437   0.430790    0.701722
# 436   0.860620    0.701722

# %%
start = time.time()

freq_ap_it = apriori(
    basket_df_small_it,
    min_support=MIN_SUPPORT,
    use_colnames=True,
    max_len=2
)

t_ap_it = time.time() - start
print("Apriori time IT:", t_ap_it)
print("Nr itemsets IT:", len(freq_ap_it))


start = time.time()
rules_ap_it = association_rules(
    freq_ap_it,
    metric="confidence",
    min_threshold=0.3
)
t_ap_rules_it = time.time() - start

rules_ap_it = rules_ap_it[rules_ap_it["lift"] > 1.0].copy()

print("Apriori rules time IT:", t_ap_rules_it)
print("Nr rules IT:", len(rules_ap_it))

rules_ap_it.sort_values(
    ["lift", "confidence"],
    ascending=False
).head(10)
# Out:
# Apriori time IT: 0.09719014167785645
# Nr itemsets IT: 939
# Apriori rules time IT: 0.008046865463256836
# Nr rules IT: 698
#                           antecedents                       consequents  \
# 517                   (Cucumber, raw)   (Red chicory, "Radicchio", raw)
# 516   (Red chicory, "Radicchio", raw)                   (Cucumber, raw)
# 572   (Red chicory, "Radicchio", raw)                     (Fennel, raw)
# 571                     (Fennel, raw)   (Red chicory, "Radicchio", raw)
# 962       (Yeast, beer yeast tablets)      (Vegetable oil, mixed seeds)
# 961      (Vegetable oil, mixed seeds)       (Yeast, beer yeast tablets)
# 514                   (Cucumber, raw)                     (Fennel, raw)
# 513                     (Fennel, raw)                   (Cucumber, raw)
# 370  (Cheese, Mozzarella, cow's milk)       (Yeast, beer yeast tablets)
# 369       (Yeast, beer yeast tablets)  (Cheese, Mozzarella, cow's milk)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 517            0.089377            0.110041  0.064801    0.725028  6.588701
# 516            0.110041            0.089377  0.064801    0.588879  6.588701
# 572            0.110041            0.134718  0.083659    0.760255  5.643324
# 571            0.134718            0.110041  0.083659    0.620998  5.643324
# 962            0.137627            0.156385  0.120975    0.879009  5.620807
# 961            0.156385            0.137627  0.120975    0.773573  5.620807
# 514            0.089377            0.134718  0.064701    0.723906  5.373504
# 513            0.134718            0.089377  0.064701    0.480268  5.373504
# 370            0.241749            0.137627  0.123082    0.509129  3.699346
# 369            0.137627            0.241749  0.123082    0.894315  3.699346
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 517               1.0  0.054966    3.236544       0.931478  0.481371
# 516               1.0  0.054966    2.214974       0.953106  0.481371
# 572               1.0  0.068835    3.609182       0.924537  0.519303
# 571               1.0  0.068835    2.348163       0.950903  0.519303
# 962               1.0  0.099452    6.972531       0.953287  0.699130
# 961               1.0  0.099452    3.808612       0.974484  0.699130
# 514               1.0  0.052660    3.134011       0.893786  0.405916
# 513               1.0  0.052660    1.752101       0.940620  0.405916
# 370               1.0  0.089810    1.756821       0.962323  0.480235
# 369               1.0  0.089810    7.174619       0.846132  0.480235
#
#      certainty  kulczynski
# 517   0.691028    0.656953
# 516   0.548527    0.656953
# 572   0.722929    0.690627
# 571   0.574135    0.690627
# 962   0.856580    0.826291
# 961   0.737437    0.826291
# 514   0.680920    0.602087
# 513   0.429257    0.602087
# 370   0.430790    0.701722
# 369   0.860620    0.701722

# %%
summary_it = pd.DataFrame([
    {
        "Algoritm": "FP-Growth",
        "time_itemsets": t_fp_it,
        "nr_itemsets": len(freq_fp_it),
        "time_rules": t_rules_it,
        "nr_rules": len(rules_fp_it)
    },
    {
        "Algoritm": "Apriori",
        "time_itemsets": t_ap_it,
        "nr_itemsets": len(freq_ap_it),
        "time_rules": t_ap_rules_it,
        "nr_rules": len(rules_ap_it)
    },
])

summary_it
# Out:
#     Algoritm  time_itemsets  nr_itemsets  time_rules  nr_rules
# 0  FP-Growth      33.754283          939    0.014131       698
# 1    Apriori       0.097190          939    0.008047       698

# %%
basket_sizes_it = [len(t) for t in transactions_it]

print("ITALIA – statistici generale")
print("Nr tranzacții:", len(transactions_it))
print("Nr item-uri unice:", basket_df_it.shape[1])
print("Dimensiune coș (min / medie / max):",
      min(basket_sizes_it),
      round(np.mean(basket_sizes_it), 2),
      max(basket_sizes_it))
# Out:
# ITALIA – statistici generale
# Nr tranzacții: 9969
# Nr item-uri unice: 1112
# Dimensiune coș (min / medie / max): 1 21.98 51

# %%
summary_countries = pd.DataFrame([
    {
        "Country": "Romania",
        "Transactions": len(transactions),
        "Items": basket_df.shape[1],
        "Rules": len(rules_fp)
    },
    {
        "Country": "Italy",
        "Transactions": len(transactions_it),
        "Items": basket_df_it.shape[1],
        "Rules": len(rules_fp_it)
    }
])

summary_countries
# Out:
#    Country  Transactions  Items  Rules
# 0  Romania          9666   1033    839
# 1    Italy          9969   1112    698

# %%
rules_ro_tbl = (
    rules_fp[
        ["antecedents", "consequents", "support", "confidence", "lift"]
    ]
    .copy()
)
rules_ro_tbl["Country"] = "Romania"

rules_it_tbl = (
    rules_fp_it[
        ["antecedents", "consequents", "support", "confidence", "lift"]
    ]
    .copy()
)
rules_it_tbl["Country"] = "Italy"

rules_compare = pd.concat(
    [rules_ro_tbl, rules_it_tbl],
    ignore_index=True
)

print("Top 5 reguli – România (FP-Growth)")
display(
    rules_compare
        .query("Country == 'Romania'")
        .sort_values(["lift", "confidence"], ascending=False)
        .head(5)
)

print("Top 5 reguli – Italia (FP-Growth)")
display(
    rules_compare
        .query("Country == 'Italy'")
        .sort_values(["lift", "confidence"], ascending=False)
        .head(5)
)
# Out:
# Top 5 reguli – România (FP-Growth)
#           antecedents        consequents   support  confidence      lift  \
# 694  (PASTA, NOODLES)    (CHICKEN BROTH)  0.095282    0.598052  6.269816
# 693   (CHICKEN BROTH)   (PASTA, NOODLES)  0.095282    0.998915  6.269816
# 683   (CHICKEN BROTH)     (POULTRY MEAT)  0.095386    1.000000  5.788024
# 682    (POULTRY MEAT)    (CHICKEN BROTH)  0.095386    0.552096  5.788024
# 552           (PASTA)  (CHEESE, TELEMEA)  0.050383    0.619593  5.714680
#
#      Country
# 694  Romania
# 693  Romania
# 683  Romania
# 682  Romania
# 552  Romania
# Top 5 reguli – Italia (FP-Growth)
#                           antecedents                      consequents  \
# 1277                  (Cucumber, raw)  (Red chicory, "Radicchio", raw)
# 1276  (Red chicory, "Radicchio", raw)                  (Cucumber, raw)
# 1267  (Red chicory, "Radicchio", raw)                    (Fennel, raw)
# 1266                    (Fennel, raw)  (Red chicory, "Radicchio", raw)
# 1160      (Yeast, beer yeast tablets)     (Vegetable oil, mixed seeds)
#
#        support  confidence      lift Country
# 1277  0.064801    0.725028  6.588701   Italy
# 1276  0.064801    0.588879  6.588701   Italy
# 1267  0.083659    0.760255  5.643324   Italy
# 1266  0.083659    0.620998  5.643324   Italy
# 1160  0.120975    0.879009  5.620807   Italy
